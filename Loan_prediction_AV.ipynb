# %%
# !pip install jovian --upgrade -q
# Out:
#      |████████████████████████████████| 71kB 2.3MB/s
# ...

# %%
import jovian

# %%
jovian.commit(project='Loan-prediction-Analytics-vidhya')
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Error: Colab File Id is not provided
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ··········
# [jovian] Uploading colab notebook to Jovian...
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-3-577a24e775fb> in <module>()
# ----> 1 jovian.commit(project='Loan-prediction-Analytics-vidhya')
#
# /usr/local/lib/python3.6/dist-packages/jovian/utils/commit.py in commit(message, files, outputs, environment, privacy, filename, project, new_project, git_commit, git_message, **kwargs)
#     131             return
#     132
# --> 133         res = perform_colab_commit(project, privacy)
#     134         username = res['owner']['username']
#     135         title = res['title']
#
# /usr/local/lib/python3.6/dist-packages/jovian/utils/colab.py in perform_colab_commit(project, privacy)
# ...

# %%
# !wget 'https://datahack-prod.s3.amazonaws.com/train_file/train_ctrUa4K.csv' -O train.csv
# Out:
# --2020-09-03 13:38:01--  https://datahack-prod.s3.amazonaws.com/train_file/train_ctrUa4K.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.66.80
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.66.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38011 (37K) [text/csv]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  37.12K   149KB/s    in 0.2s
#
# 2020-09-03 13:38:03 (149 KB/s) - ‘train.csv’ saved [38011/38011]

# %%
# !wget https://datahack-prod.s3.amazonaws.com/test_file/test_lAUu6dG.csv -O test.csv
# Out:
# --2020-09-03 13:38:40--  https://datahack-prod.s3.amazonaws.com/test_file/test_lAUu6dG.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.66.52
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.66.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21955 (21K) [text/csv]
# Saving to: ‘test.csv’
#
# test.csv            100%[===================>]  21.44K  86.1KB/s    in 0.2s
#
# 2020-09-03 13:38:41 (86.1 KB/s) - ‘test.csv’ saved [21955/21955]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
test_df = pd.read_csv('train.csv')
test_df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ### Handling NUll Values

# %%
categorical_columns = ['Gender', 'Married', 'Self_Employed']
categorical_data = test_df[categorical_columns]
categorical_data.isna().sum()
# Out:
# Gender           13
# Married           3
# Self_Employed    32
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
categorical_impute = SimpleImputer()
